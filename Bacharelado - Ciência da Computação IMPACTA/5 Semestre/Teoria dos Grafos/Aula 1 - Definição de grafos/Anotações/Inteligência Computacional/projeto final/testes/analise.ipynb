# %%
# Célula 0 — Instalar dependências
! pip install pandas
! pip install matplotlib
! pip install openpyxl
! pip install os
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
# Célula 2 — Conferir diretório atual
os.getcwd()
# Out:
# 'c:\\Users\\2401895\\Documents\\GitHub\\dev\\Bacharelado - Ciência da Computação IMPACTA\\5 Semestre\\Teoria dos Grafos\\Aula 1 - Definição de grafos\\Anotações\\Inteligência Computacional\\projeto final\\testes'

# %%
# Célula 3 — Importar bibliotecas

import pandas as pd
import matplotlib.pyplot as plt
import os
from pathlib import Path

# %%
# Célula 4 — Carregar dados
caminho = Path("..") / "base" / "br_seeg_emissoes.xlsx"
df = pd.read_excel(caminho)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 # Célula 4 — Carregar dados
#       2 caminho = Path("..") / "base" / "br_seeg_emissoes.xlsx"
# ----> 3 df = pd.read_excel(caminho)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
# Célula 5 — Inspeção inicial dos dados
df.head()
df.columns
df.info()

# %%
# Célula 6 — Limpeza e tipos de dados
df["ano"] = df["ano"].astype(int)
df["emissao"] = pd.to_numeric(df["emissao"], errors="coerce")
df.info()
